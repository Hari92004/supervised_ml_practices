# %%
import pandas as pd
import numpy as np

# %%
new_data=pd.read_csv(r"D:\user\Downloads\Aadhar_Data.csv.csv",on_bad_lines='skip')
print(new_data.head)
# Out:
# <bound method NDFrame.head of              date   state     district  pincode  age_0_5  age_5_17  \
# 0      01-09-2025  Odisha        Angul   759022        2         0
# 1      01-09-2025  Odisha        Angul   759100        1         1
# 2      01-07-2025  Odisha      Khordha   751024       37        37
# 3      01-07-2025  Odisha  Nabarangpur   764074      327       103
# 4      03-09-2025  Odisha        Angul   759117        1         0
# ...           ...     ...          ...      ...      ...       ...
# 51428  19-06-2025  Odisha      Sonapur   767023        4         0
# 51429  19-06-2025  Odisha   Sundergarh   769003        2         1
# 51430  19-06-2025  Odisha   Sundergarh   770001        1         0
# 51431  19-06-2025  Odisha   Sundergarh   770013        1         0
# 51432  19-06-2025  Odisha   Sundergarh   770037        8         1
#
#        age_18_greater
# 0                   0
# 1                   0
# 2                  13
# 3                  12
# ...

# %%
odisha_districts = [
    "Angul",
    "Boudh",
    "Balangir",
    "Bargarh",
    "Balasore",
    "Bhadrak",
    "Cuttack",
    "Deogarh",
    "Dhenkanal",
    "Ganjam",
    "Gajapati",
    "Jharsuguda",
    "Jajpur",
    "Jagatsinghapur",
    "Khordha",
    "Keonjhar",
    "Kalahandi",
    "Kandhamal",
    "Koraput",
    "Kendrapara",
    "Malkangiri",
    "Mayurbhanj",
    "Nabarangpur",
    "Nuapada",
    "Nayagarh",
    "Puri",
    "Rayagada",
    "Sambalpur",
    "Subarnapur",
    "Sundargarh"
]

# %%
new_data["Migration"] = np.random.choice(odisha_districts, size=len(new_data))

# %%
new_data.to_csv("loanData_with_migration.csv", index=False)
